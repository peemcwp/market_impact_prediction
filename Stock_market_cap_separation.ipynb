# %%
import pandas as pd

# %%
# Small cap stock
SEHK_2 = pd.read_csv("SEHK_2_MIC.csv")
SEHK_2
# Out:
#      Volatility      Size       POV      Cost
# 0        0.0031  0.226847  0.033508  0.838879
# 1        0.0033  0.280619  0.032478  0.865851
# 2        0.0034  0.246475  0.033550  1.062358
# 3        0.0035  0.199725  0.033750  1.145059
# 4        0.0036  0.208105  0.033480  0.951677
# 5        0.0037  0.184017  0.033088  1.226993
# 6        0.0038  0.179350  0.033563  0.824934
# 7        0.0039  0.178400  0.033582  1.051339
# 8        0.0040  0.196655  0.033735  1.042407
# 9        0.0041  0.174396  0.033619  1.076183
# 10       0.0042  0.184976  0.033500  0.979437
# 11       0.0043  0.211721  0.033679  0.945747
# 12       0.0044  0.176482  0.033521  0.812094
# 13       0.0045  0.188263  0.033219  0.950666
# 14       0.0046  0.207930  0.033783  1.057620
# 15       0.0047  0.165783  0.033472  0.934868
# 16       0.0048  0.167752  0.034043  0.685287
# 17       0.0049  0.184182  0.033658  0.981735
# 18       0.0050  0.188291  0.033690  0.907908
# ...

# %%
test = pd.cut(SEHK_2['Volatility'], 1000)
test
#  labels=np.arange(0.01, 1.01, 0.001)
# Out:
# 0        (0.00305, 0.00315]
# 1      (0.003299, 0.003349]
# 2      (0.003399, 0.003449]
# 3      (0.003498, 0.003548]
# 4      (0.003598, 0.003648]
# 5      (0.003698, 0.003747]
# 6      (0.003797, 0.003847]
# 7      (0.003897, 0.003947]
# 8      (0.003996, 0.004046]
# 9      (0.004096, 0.004146]
# 10     (0.004196, 0.004245]
# 11     (0.004295, 0.004345]
# 12     (0.004395, 0.004445]
# 13     (0.004494, 0.004544]
# 14     (0.004594, 0.004644]
# 15     (0.004694, 0.004743]
# 16     (0.004793, 0.004843]
# 17     (0.004893, 0.004943]
# 18     (0.004992, 0.005042]
# 19     (0.005092, 0.005142]
# 20     (0.005192, 0.005241]
# 21     (0.005291, 0.005341]
# 22     (0.005391, 0.005441]
# 23       (0.00549, 0.00554]
# 24       (0.00559, 0.00564]
# 25      (0.00569, 0.005739]
# 26     (0.005789, 0.005839]
# 27     (0.005889, 0.005939]
# 28     (0.005988, 0.006038]
# 29     (0.006088, 0.006138]
#                ...
# 206      (0.03059, 0.03064]
# 207      (0.03109, 0.03114]
# ...

# %%
import numpy as np

range = np.arange(0.001, 1.001, 0.001)
print(len(range))
range
# Out:
# 1000
# array([ 0.001,  0.002,  0.003,  0.004,  0.005,  0.006,  0.007,  0.008,
#         0.009,  0.01 ,  0.011,  0.012,  0.013,  0.014,  0.015,  0.016,
#         0.017,  0.018,  0.019,  0.02 ,  0.021,  0.022,  0.023,  0.024,
#         0.025,  0.026,  0.027,  0.028,  0.029,  0.03 ,  0.031,  0.032,
#         0.033,  0.034,  0.035,  0.036,  0.037,  0.038,  0.039,  0.04 ,
#         0.041,  0.042,  0.043,  0.044,  0.045,  0.046,  0.047,  0.048,
#         0.049,  0.05 ,  0.051,  0.052,  0.053,  0.054,  0.055,  0.056,
#         0.057,  0.058,  0.059,  0.06 ,  0.061,  0.062,  0.063,  0.064,
#         0.065,  0.066,  0.067,  0.068,  0.069,  0.07 ,  0.071,  0.072,
#         0.073,  0.074,  0.075,  0.076,  0.077,  0.078,  0.079,  0.08 ,
#         0.081,  0.082,  0.083,  0.084,  0.085,  0.086,  0.087,  0.088,
#         0.089,  0.09 ,  0.091,  0.092,  0.093,  0.094,  0.095,  0.096,
#         0.097,  0.098,  0.099,  0.1  ,  0.101,  0.102,  0.103,  0.104,
# ...
