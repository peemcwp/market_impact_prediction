# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
df1 = pd.read_csv('SEHK_2_MIC.csv')

# Split test set and train set

X1_all, y1_all = df1[['Size', 'Volatility', 'POV']], df1['Cost']

X1_train, X1_test, y1_train, y1_test = train_test_split(X1_all, y1_all, test_size=0.3, random_state=0)

# %%
df2 = pd.read_csv('SEHK_3_MIC.csv')

# Split test set and train set

X2_all, y2_all = df2[['Size', 'Volatility', 'POV']], df2['Cost']

X2_train, X2_test, y2_train, y2_test = train_test_split(X2_all, y2_all, test_size=0.3, random_state=0)

# %%
df3 = pd.read_csv('SEHK_6_MIC.csv')

# Split test set and train set

X3_all, y3_all = df3[['Size', 'Volatility', 'POV']], df3['Cost']

X3_train, X3_test, y3_train, y3_test = train_test_split(X3_all, y3_all, test_size=0.3, random_state=0)

# %%
df4 = pd.read_csv('SEHK_12_MIC.csv')

# Split test set and train set

X4_all, y4_all = df4[['Size', 'Volatility', 'POV']], df4['Cost']

X4_train, X4_test, y4_train, y4_test = train_test_split(X4_all, y4_all, test_size=0.3, random_state=0)

# %%
df5 = pd.read_csv('SEHK_16_MIC.csv')

# Split test set and train set

X5_all, y5_all = df5[['Size', 'Volatility', 'POV']], df5['Cost']

X5_train, X5_test, y5_train, y5_test = train_test_split(X5_all, y5_all, test_size=0.3, random_state=0)

# %%
df6 = pd.read_csv('SEHK_17_MIC.csv')

# Split test set and train set

X6_all, y6_all = df6[['Size', 'Volatility', 'POV']], df6['Cost']

X6_train, X6_test, y6_train, y6_test = train_test_split(X6_all, y6_all, test_size=0.3, random_state=0)

# %%
df7 = pd.read_csv('SEHK_23_MIC.csv')

# Split test set and train set

X7_all, y7_all = df7[['Size', 'Volatility', 'POV']], df7['Cost']

X7_train, X7_test, y7_train, y7_test = train_test_split(X7_all, y7_all, test_size=0.3, random_state=0)

# %%
df8 = pd.read_csv('SEHK_27_MIC.csv')

# Split test set and train set

X8_all, y8_all = df8[['Size', 'Volatility', 'POV']], df8['Cost']

X8_train, X8_test, y8_train, y8_test = train_test_split(X8_all, y8_all, test_size=0.3, random_state=0)

# %%
df9 = pd.read_csv('SEHK_83_MIC.csv')

# Split test set and train set

X9_all, y9_all = df9[['Size', 'Volatility', 'POV']], df9['Cost']

X9_train, X9_test, y9_train, y9_test = train_test_split(X9_all, y9_all, test_size=0.3, random_state=0)

# %%
df10 = pd.read_csv('SEHK_101_MIC.csv')

# Split test set and train set

X10_all, y10_all = df10[['Size', 'Volatility', 'POV']], df10['Cost']

X10_train, X10_test, y10_train, y10_test = train_test_split(X10_all, y10_all, test_size=0.3, random_state=0)

# %%
df11 = pd.read_csv('SEHK_267_MIC.csv')

# Split test set and train set

X11_all, y11_all = df11[['Size', 'Volatility', 'POV']], df11['Cost']

X11_train, X11_test, y11_train, y11_test = train_test_split(X11_all, y11_all, test_size=0.3, random_state=0)

# %%
df12 = pd.read_csv('SEHK_386_MIC.csv')

# Split test set and train set

X12_all, y12_all = df12[['Size', 'Volatility', 'POV']], df12['Cost']

X12_train, X12_test, y12_train, y12_test = train_test_split(X12_all, y12_all, test_size=0.3, random_state=0)

# %%
df13 = pd.read_csv('SEHK_836_MIC.csv')

# Split test set and train set

X13_all, y13_all = df13[['Size', 'Volatility', 'POV']], df13['Cost']

X13_train, X13_test, y13_train, y13_test = train_test_split(X13_all, y13_all, test_size=0.3, random_state=0)

# %%
df14 = pd.read_csv('SEHK_883_MIC.csv')

# Split test set and train set

X14_all, y14_all = df14[['Size', 'Volatility', 'POV']], df14['Cost']

X14_train, X14_test, y14_train, y14_test = train_test_split(X14_all, y14_all, test_size=0.3, random_state=0)

# %%
df15 = pd.read_csv('SEHK_941_MIC.csv')

# Split test set and train set

X15_all, y15_all = df15[['Size', 'Volatility', 'POV']], df15['Cost']

X15_train, X15_test, y15_train, y15_test = train_test_split(X15_all, y15_all, test_size=0.3, random_state=0)

# %%
df16 = pd.read_csv('SEHK_1038_MIC.csv')

# Split test set and train set

X16_all, y16_all = df16[['Size', 'Volatility', 'POV']], df16['Cost']

X16_train, X16_test, y16_train, y16_test = train_test_split(X16_all, y16_all, test_size=0.3, random_state=0)

# %%
df17 = pd.read_csv('SEHK_1044_MIC.csv')

# Split test set and train set

X17_all, y17_all = df17[['Size', 'Volatility', 'POV']], df17['Cost']

X17_train, X17_test, y17_train, y17_test = train_test_split(X17_all, y17_all, test_size=0.3, random_state=0)

# %%
df18 = pd.read_csv('SEHK_1093_MIC.csv')

# Split test set and train set

X18_all, y18_all = df18[['Size', 'Volatility', 'POV']], df18['Cost']

X18_train, X18_test, y18_train, y18_test = train_test_split(X18_all, y18_all, test_size=0.3, random_state=0)

# %%
df19 = pd.read_csv('SEHK_1109_MIC.csv')

# Split test set and train set

X19_all, y19_all = df19[['Size', 'Volatility', 'POV']], df19['Cost']

X19_train, X19_test, y19_train, y19_test = train_test_split(X19_all, y19_all, test_size=0.3, random_state=0)

# %%
df20 = pd.read_csv('SEHK_1299_MIC.csv')

# Split test set and train set

X20_all, y20_all = df20[['Size', 'Volatility', 'POV']], df20['Cost']

X20_train, X20_test, y20_train, y20_test = train_test_split(X20_all, y20_all, test_size=0.3, random_state=0)

# %%
df21 = pd.read_csv('SEHK_1398_MIC.csv')

# Split test set and train set

X21_all, y21_all = df21[['Size', 'Volatility', 'POV']], df21['Cost']

X21_train, X21_test, y21_train, y21_test = train_test_split(X21_all, y21_all, test_size=0.3, random_state=0)

# %%
df22 = pd.read_csv('SEHK_1928_MIC.csv')

# Split test set and train set

X22_all, y22_all = df22[['Size', 'Volatility', 'POV']], df22['Cost']

X22_train, X22_test, y22_train, y22_test = train_test_split(X22_all, y22_all, test_size=0.3, random_state=0)

# %%
df23 = pd.read_csv('SEHK_2018_MIC.csv')

# Split test set and train set

X23_all, y23_all = df23[['Size', 'Volatility', 'POV']], df23['Cost']

X23_train, X23_test, y23_train, y23_test = train_test_split(X23_all, y23_all, test_size=0.3, random_state=0)

# %%
df24 = pd.read_csv('SEHK_2318_MIC.csv')

# Split test set and train set

X24_all, y24_all = df24[['Size', 'Volatility', 'POV']], df24['Cost']

X24_train, X24_test, y24_train, y24_test = train_test_split(X24_all, y24_all, test_size=0.3, random_state=0)

# %%
df25 = pd.read_csv('SEHK_2319_MIC.csv')

# Split test set and train set

X25_all, y25_all = df25[['Size', 'Volatility', 'POV']], df25['Cost']

X25_train, X25_test, y25_train, y25_test = train_test_split(X25_all, y25_all, test_size=0.3, random_state=0)

# %%
df26 = pd.read_csv('SEHK_2388_MIC.csv')

# Split test set and train set

X26_all, y26_all = df26[['Size', 'Volatility', 'POV']], df26['Cost']

X26_train, X26_test, y26_train, y26_test = train_test_split(X26_all, y26_all, test_size=0.3, random_state=0)

# %%
X_train = pd.concat([X1_train, X2_train, X3_train, X4_train, X5_train, X6_train, X7_train, X8_train, X9_train, X10_train, X11_train, X12_train, X13_train, X14_train, X15_train, X16_train, X17_train, X18_train, X19_train, X20_train, X21_train, X22_train, X23_train, X24_train, X25_train, X26_train], ignore_index=True)
X_train
# Out:
#           Size  Volatility       POV
# 0     0.202680      0.0084  0.033445
# 1     0.142482      0.0098  0.033630
# 2     0.206277      0.0058  0.033388
# 3     0.160731      0.0108  0.033761
# 4     0.102424      0.0355  0.031132
# 5     0.129783      0.0316  0.033339
# 6     0.194884      0.0072  0.033831
# 7     0.188263      0.0045  0.033219
# 8     0.199725      0.0035  0.033750
# 9     0.171304      0.0176  0.033857
# 10    0.189368      0.0056  0.033583
# 11    0.206444      0.0062  0.033608
# 12    0.210408      0.0326  0.034812
# 13    0.196196      0.0092  0.033815
# 14    0.202674      0.0088  0.033617
# 15    0.283006      0.0161  0.034350
# 16    0.214879      0.0142  0.033184
# 17    0.209508      0.0051  0.033658
# 18    0.197250      0.0238  0.033635
# 19    0.271702      0.0156  0.033828
# 20    0.206110      0.0086  0.033728
# 21    0.336230      0.0265  0.034098
# 22    0.158111      0.0112  0.033461
# 23    0.149033      0.0083  0.033661
# ...

# %%
y_train = pd.concat([y1_train, y2_train, y3_train, y4_train, y5_train, y6_train, y7_train, y8_train, y9_train, y10_train, y11_train, y12_train, y13_train, y14_train, y15_train, y16_train, y17_train, y18_train, y19_train, y20_train, y21_train, y22_train, y23_train, y24_train, y25_train, y26_train], ignore_index=True)
y_train
# Out:
# 0       1.005453
# 1       1.069830
# 2       1.027715
# 3       1.232809
# 4       2.689894
# 5       3.837492
# 6       1.008869
# 7       0.950666
# 8       1.145059
# 9       1.542428
# 10      1.024357
# 11      1.017721
# 12      2.175943
# 13      1.022524
# 14      1.032972
# 15      1.429368
# 16      2.342516
# 17      1.043935
# 18      1.997808
# 19      1.116117
# 20      1.035928
# 21      2.086927
# 22      1.329465
# 23      0.957592
# 24      1.364141
# 25      1.820656
# 26      2.214834
# 27      1.281144
# 28      1.769388
# 29      1.693525
#           ...
# 6774    4.011975
# 6775    3.567787
# 6776    2.801419
# 6777    3.011825
# 6778    3.556331
# 6779    2.748814
# 6780    2.322816
# 6781    3.198566
# 6782    4.315752
# 6783    3.011824
# 6784    3.650792
# 6785    3.113714
# 6786    4.186509
# 6787    2.793173
# 6788    3.845665
# 6789    3.218711
# 6790    3.314369
# 6791    3.487642
# 6792    6.219882
# 6793    3.601574
# 6794    4.092381
# ...

# %%
X_test = pd.concat([X1_test, X2_test, X3_test, X4_test, X5_test, X6_test, X7_test, X8_test, X9_test, X10_test, X11_test, X12_test, X13_test, X14_test, X15_test, X16_test, X17_test, X18_test, X19_test, X20_test, X21_test, X22_test, X23_test, X24_test, X25_test, X26_test])

# %%
y_test = pd.concat([y1_test, y2_test, y3_test, y4_test, y5_test, y6_test, y7_test, y8_test, y9_test, y10_test, y11_test, y12_test, y13_test, y14_test, y15_test, y16_test, y17_test, y18_test, y19_test, y20_test, y21_test, y22_test, y23_test, y24_test, y25_test, y26_test])

# %%
X_train_low = pd.concat([X1_train, X2_train, X3_train, X7_train, X15_train, X16_train, X20_train])
X_test_low = pd.concat([X1_test, X2_test, X3_test, X7_test, X15_test, X16_test, X20_test])

y_train_low = pd.concat([y1_train, y2_train, y3_train, y7_train, y15_train, y16_train, y20_train])
y_test_low = pd.concat([y1_test, y2_test, y3_test, y7_test, y15_test, y16_test, y20_test])

# %%
X_train_medium = pd.concat([X4_train, X6_train, X9_train, X10_train, X12_train, X13_train, X14_train, X17_train, X21_train, X22_train, X26_train])
X_test_medium = pd.concat([X4_test, X6_test, X9_test, X10_test, X12_test, X13_test, X14_test, X17_test, X21_test, X22_test, X26_test])

y_train_medium = pd.concat([y4_train, y6_train, y9_train, y10_train, y12_train, y13_train, y14_train, y17_train, y21_train, y22_train, y26_train])
y_test_medium = pd.concat([y4_test, y6_test, y9_test, y10_test, y12_test, y13_test, y14_test, y17_test, y21_test, y22_test, y26_test])

# %%
X_train_high = pd.concat([X5_train, X8_train, X11_train, X18_train, X19_train, X23_train, X24_train, X25_train])
X_test_high = pd.concat([X5_test, X8_test, X11_test, X18_test, X19_test, X23_test, X24_test, X25_test])

y_train_high = pd.concat([y5_train, y8_train, y11_train, y18_train, y19_train, y23_train, y24_train, y25_train])
y_test_high = pd.concat([y5_test, y8_test, y11_test, y18_test, y19_test, y23_test, y24_test, y25_test])

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_low(X_train, X_test, y_train, y_test):
    model = SVR(C=50.0, kernel="linear", epsilon=1.0)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=50.0, epsilon=1.0, kernel="linear")
model_SVR.fit(X_train_low, y_train_low)
preds = model_SVR.predict(X_test_low)

test_val = y_test_low
preds_val = preds
ar = np.arange(len(y_test_low))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')

SVR_MSE_low = SVR_score_low(X_train_low, X_test_low, y_train_low, y_test_low)[0]
SVR_MAE_low = SVR_score_low(X_train_low, X_test_low, y_train_low, y_test_low)[1]
plt.plot()
plt.show()
print("=======================================================")
print("SVR model RMSE of random predictions on low volatility stocks: {}".format(SVR_MSE_low**(1/2)))
print("SVR model MAE of random predictions on low volatility stocks: {}".format(SVR_MAE_low))
# Out:
# ...
# SVR model RMSE of random predictions on low volatility stocks: 0.8554799499603261
# SVR model MAE of random predictions on low volatility stocks: 0.6615651528026186

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_medium(X_train, X_test, y_train, y_test):
    model = SVR(C=100.0, kernel="rbf", epsilon=0.3)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=100.0, epsilon=0.3, kernel="rbf")
model_SVR.fit(X_train_medium, y_train_medium)
preds = model_SVR.predict(X_test_medium)

test_val = y_test_medium
preds_val = preds
ar = np.arange(len(y_test_medium))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')
SVR_MSE_medium = SVR_score_medium(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[0]
SVR_MAE_medium = SVR_score_medium(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[1]

plt.plot()
plt.show()
print("=======================================================")
print("SVR model RMSE of random predictions on medium volatility stocks: {}".format(SVR_MSE_medium**(1/2)))
print("SVR model MAE of random predictions on medium volatility stocks: {}".format(SVR_MAE_medium))
# Out:
# ...
# SVR model RMSE of random predictions on medium volatility stocks: 1.0001056281134955
# SVR model MAE of random predictions on medium volatility stocks: 0.6859947951747403

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_high(X_train, X_test, y_train, y_test):
    model = SVR(C=100.0, kernel="linear", epsilon=0.7)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=100.0, epsilon=0.7, kernel="linear")
model_SVR.fit(X_train_high, y_train_high)
preds = model_SVR.predict(X_test_high)

test_val = y_test_high
preds_val = preds
ar = np.arange(len(y_test_high))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')
SVR_MSE_high = SVR_score_high(X_train_high, X_test_high, y_train_high, y_test_high)[0]
SVR_MAE_high = SVR_score_high(X_train_high, X_test_high, y_train_high, y_test_high)[1]

plt.plot()
plt.show()
print("=======================================================")
print("SVR model RMSE of random predictions on high volatility stocks: {}".format(SVR_MSE_high**(1/2)))
print("SVR model MAE of random predictions on high volatility stocks: {}".format(SVR_MAE_high))
# Out:
# ...
# SVR model RMSE of random predictions on high volatility stocks: 1.6833304306815537
# SVR model MAE of random predictions on high volatility stocks: 0.8623792637584503

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

np.random.seed(0)
y = y_train_low
X = X_train_low
parameters = {'kernel': ['rbf'], 'C': np.logspace(-9, 9, num=25, base=10), 'epsilon': np.logspace(-9, 9, num=25, base=10)}

from evolutionary_search import EvolutionaryAlgorithmSearchCV

cv = EvolutionaryAlgorithmSearchCV(estimator=SVR(),
                                   params=parameters,
                                   cv=3,
                                   population_size=50,
                                   gene_mutation_prob=0.10,
                                   gene_crossover_prob=0.5,
                                   tournament_size=3,
                                   generations_number=5,
                                   n_jobs=4)
# %time cv.fit(X, y)

cv.best_params_
# Out:
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# {'C': 177827.94100389228, 'epsilon': 0.17782794100389229, 'kernel': 'rbf'}

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

np.random.seed(0)
y = y_train_medium
X = X_train_medium
parameters = {'kernel': ['rbf'], 'C': np.logspace(-9, 9, num=25, base=10), 'epsilon': np.logspace(-9, 9, num=25, base=10)}

from evolutionary_search import EvolutionaryAlgorithmSearchCV

cv = EvolutionaryAlgorithmSearchCV(estimator=SVR(),
                                   params=parameters,
                                   cv=3,
                                   population_size=50,
                                   gene_mutation_prob=0.10,
                                   gene_crossover_prob=0.5,
                                   tournament_size=3,
                                   generations_number=5,
                                   n_jobs=4)
# %time cv.fit(X, y)

cv.best_params_
# Out:
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# CPU times: user 1.62 s, sys: 330 ms, total: 1.95 s
# Wall time: 5min 36s
# {'C': 5623.4132519034911, 'epsilon': 0.005623413251903491, 'kernel': 'rbf'}

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

np.random.seed(0)
y = y_train_high
X = X_train_high
parameters = {'kernel': ['rbf'], 'C': np.logspace(-9, 9, num=25, base=10), 'epsilon': np.logspace(-9, 9, num=25, base=10)}

from evolutionary_search import EvolutionaryAlgorithmSearchCV

cv = EvolutionaryAlgorithmSearchCV(estimator=SVR(),
                                   params=parameters,
                                   cv=3,
                                   population_size=50,
                                   gene_mutation_prob=0.10,
                                   gene_crossover_prob=0.5,
                                   tournament_size=3,
                                   generations_number=5,
                                   n_jobs=4)
# %time cv.fit(X, y)

cv.best_params_
# Out:
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Users/chokwaphat/anaconda/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# CPU times: user 1.43 s, sys: 427 ms, total: 1.86 s
# Wall time: 9min 30s
# {'C': 31.622776601683793, 'epsilon': 0.17782794100389229, 'kernel': 'rbf'}

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_low(X_train, X_test, y_train, y_test):
    model = SVR(C=177827.94100389228, kernel="rbf", epsilon=0.17782794100389229)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=177827.94100389228, epsilon=0.17782794100389229, kernel="rbf")
model_SVR.fit(X_train_low, y_train_low)
preds = model_SVR.predict(X_test_low)

test_val = y_test_low
preds_val = preds
ar = np.arange(len(y_test_low))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')

GA_SVR_MSE_low = SVR_score_low(X_train_low, X_test_low, y_train_low, y_test_low)[0]
GA_SVR_MAE_low = SVR_score_low(X_train_low, X_test_low, y_train_low, y_test_low)[1]
plt.plot()
plt.show()
print("=======================================================")
print("GA-SVR model RMSE of random predictions on low volatility stocks: {}".format(GA_SVR_MSE_low**(1/2)))
print("GA-SVR model MAE of random predictions on low volatility stocks: {}".format(GA_SVR_MAE_low))
# Out:
# ...
# GA-SVR model RMSE of random predictions on low volatility stocks: 0.8061302568925875
# GA-SVR model MAE of random predictions on low volatility stocks: 0.5843053671826541

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_medium(X_train, X_test, y_train, y_test):
    model = SVR(C=5623.4132519034911, kernel="rbf", epsilon=0.005623413251903491)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=5623.4132519034911, epsilon=0.005623413251903491, kernel="rbf")
model_SVR.fit(X_train_medium, y_train_medium)
preds = model_SVR.predict(X_test_medium)

test_val = y_test_medium
preds_val = preds
ar = np.arange(len(y_test_medium))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')
GA_SVR_MSE_medium = SVR_score_medium(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[0]
GA_SVR_MAE_medium = SVR_score_medium(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[1]

plt.plot()
plt.show()
print("=======================================================")
print("GA-SVR model RMSE of random predictions on medium volatility stocks: {}".format(GA_SVR_MSE_medium**(1/2)))
print("GA-SVR model MAE of random predictions on medium volatility stocks: {}".format(GA_SVR_MAE_medium))
# Out:
# ...
# GA-SVR model RMSE of random predictions on medium volatility stocks: 0.9727459810430993
# GA-SVR model MAE of random predictions on medium volatility stocks: 0.6630398796639051

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

def SVR_score_high(X_train, X_test, y_train, y_test):
    model = SVR(C=177.82794100389228, kernel="rbf", epsilon=1.0)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
import matplotlib.pyplot as plt

model_SVR = SVR(C=177.82794100389228, epsilon=1.0, kernel="rbf")
model_SVR.fit(X_train_high, y_train_high)
preds = model_SVR.predict(X_test_high)

test_val = y_test_high
preds_val = preds
ar = np.arange(len(y_test_high))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (SVR)')
GA_SVR_MSE_high = SVR_score_high(X_train_high, X_test_high, y_train_high, y_test_high)[0]
GA_SVR_MAE_high = SVR_score_high(X_train_high, X_test_high, y_train_high, y_test_high)[1]

plt.plot()
plt.show()
print("=======================================================")
print("GA-SVR model RMSE of random predictions on high volatility stocks: {}".format(GA_SVR_MSE_high**(1/2)))
print("GA-SVR model MAE of random predictions on high volatility stocks: {}".format(GA_SVR_MAE_high))
# Out:
# ...
# GA-SVR model RMSE of random predictions on high volatility stocks: 1.6737298771915388
# GA-SVR model MAE of random predictions on high volatility stocks: 0.8718745630310889

# %%
from lmfit import Model, Parameters

# %%
def i_star_model(size, volatility, pov, b1, a1, a2, a3, a4):
    return ((b1 * (a1 * np.power(size, a2) * np.power(volatility, a3))) * np.power(pov, a4)) + ((1 - b1)*(a1 * np.power(size, a2) * np.power(volatility, a3)))

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
def istar_score(X_test, y_test):
    preds = i_star_model(X_test['Size'], X_test['Volatility'], X_test['POV'], b1, a1, a2, a3, a4)
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
y = y_train_low
size = X_train_low['Size']
volatility = X_train_low['Volatility']
pov = X_train_low['POV']
params = Parameters()
params.add('b1', value=0.7, min=0.7, max=1)
params.add('a1', value=100, min=100, max=1000)
params.add('a2', value=0.1, min=0.1, max=1)
params.add('a3', value=0.1, min=0.1, max=1)
params.add('a4', value=0.1, min=0.1, max=1)

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'], param_names=params)
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, params=params)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_low['Size'], X_test_low['Volatility'], X_test_low['POV'], b1, a1, a2, a3, a4)

test_val = y_test_low
preds_val = preds
ar = np.arange(len(y_test_low))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')

iStar_MSE_low = istar_score(X_test_low, y_test_low)[0]
iStar_MAE_low = istar_score(X_test_low, y_test_low)[1]

plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on low volatility stocks : {}".format(iStar_MSE_low**(1/2)))
print("I-Star model MAE of random predictions on low volatility stocks : {}".format(iStar_MAE_low))
# Out:
# [[Model]]
#     Model(i_star_model)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 66
#     # data points      = 1322
#     # variables        = 5
#     chi-square         = 908.431356
#     reduced chi-square = 0.68977324
#     Akaike info crit   = -485.990198
#     Bayesian info crit = -460.055693
# [[Variables]]
#     b1:  0.70000000 (init = 0.7)
#     a1:  100.019528 (init = 100)
#     a2:  0.10040894 (init = 0.1)
#     a3:  0.62206696 (init = 0.1)
#     a4:  0.97057529 (init = 0.1)
# ...
# I-Star model RMSE of random predictions on low volatility stocks : 0.8680006623976565
# I-Star model MAE of random predictions on low volatility stocks : 0.6634507159209019

# %%
y = y_train_low
size = X_train_low['Size']
volatility = X_train_low['Volatility']
pov = X_train_low['POV']

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'],  param_names=['b1', 'a1', 'a2', 'a3', 'a4'])
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, b1=0.7, a1=10, a2=0.1, a3=0.1, a4=0.1)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_low['Size'], X_test_low['Volatility'], X_test_low['POV'], b1, a1, a2, a3, a4)

test_val = y_test_low
preds_val = preds
ar = np.arange(len(y_test_low))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')

iStar_MSE_low = istar_score(X_test_low, y_test_low)[0]
iStar_MAE_low = istar_score(X_test_low, y_test_low)[1]

plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on low volatility stocks : {}".format(iStar_MSE_low**(1/2)))
print("I-Star model MAE of random predictions on low volatility stocks : {}".format(iStar_MAE_low))
# Out:
# [[Model]]
#     Model(i_star_model)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 615
#     # data points      = 1322
#     # variables        = 5
#     chi-square         = 816.519734
#     reduced chi-square = 0.61998461
#     Akaike info crit   = -627.005620
#     Bayesian info crit = -601.071115
# [[Variables]]
#     b1:  5.40023629 +/- 1270.87455 (23533.68%) (init = 0.7)
#     a1:  50.4032509 +/- 643.756575 (1277.21%) (init = 10)
#     a2: -0.03569721 +/- 0.01391413 (38.98%) (init = 0.1)
#     a3:  0.50388115 +/- 0.01827759 (3.63%) (init = 0.1)
#     a4:  0.04060621 +/- 10.5471490 (25974.23%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b1, a4) = -1.000
#     C(a1, a4) =  1.000
#     C(b1, a1) = -1.000
#     C(a3, a4) = -0.325
#     C(b1, a3) =  0.325
#     C(a1, a3) = -0.321
# ...
# I-Star model RMSE of random predictions on low volatility stocks : 0.8135476498272658
# ...

# %%
y = y_train_medium
size = X_train_medium['Size']
volatility = X_train_medium['Volatility']
pov = X_train_medium['POV']

params = Parameters()
params.add('b1', value=0.7, min=0.7, max=1)
params.add('a1', value=100, min=100, max=1000)
params.add('a2', value=0.1, min=0.1, max=1)
params.add('a3', value=0.1, min=0.1, max=1)
params.add('a4', value=0.1, min=0.1, max=1)

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'], param_names=params)
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, params=params)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_medium['Size'], X_test_medium['Volatility'], X_test_medium['POV'], b1, a1, a2, a3, a4)
test_val = y_test_medium
preds_val = preds
ar = np.arange(len(y_test_medium))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')
iStar_MSE_medium = istar_score(X_test_medium, y_test_medium)[0]
iStar_MAE_medium = istar_score(X_test_medium, y_test_medium)[1]


plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on medium volatility stocks : {}".format(iStar_MSE_medium**(1/2)))
print("I-Star model MAE of random predictions on medium volatility stocks : {}".format(iStar_MAE_medium))

# %%
y = y_train_medium
size = X_train_medium['Size']
volatility = X_train_medium['Volatility']
pov = X_train_medium['POV']

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'],  param_names=['b1', 'a1', 'a2', 'a3', 'a4'])
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, b1=0.7, a1=10, a2=0.1, a3=0.1, a4=0.1)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_medium['Size'], X_test_medium['Volatility'], X_test_medium['POV'], b1, a1, a2, a3, a4)

test_val = y_test_medium
preds_val = preds
ar = np.arange(len(y_test_medium))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')

iStar_MSE_medium = istar_score(X_test_medium, y_test_medium)[0]
iStar_MAE_medium = istar_score(X_test_medium, y_test_medium)[1]

plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on medium volatility stocks : {}".format(iStar_MSE_medium**(1/2)))
print("I-Star model MAE of random predictions on medium volatility stocks : {}".format(iStar_MAE_medium))
# Out:
# [[Model]]
#     Model(i_star_model)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 8637
#     # data points      = 2999
#     # variables        = 5
#     chi-square         = 2584.40500
#     reduced chi-square = 0.86319472
#     Akaike info crit   = -436.201999
#     Bayesian info crit = -406.171828
# [[Variables]]
#     b1:  1.00000000 +/- 6.8833e-11 (0.00%) (init = 0.7)
#     a1:  4.2050e+11 +/- 2.3005e+12 (547.10%) (init = 10)
#     a2: -0.30140648 +/- 0.00732430 (2.43%) (init = 0.1)
#     a3:  0.38793513 +/- 0.01003690 (2.59%) (init = 0.1)
#     a4:  7.76069886 +/- 1.70119021 (21.92%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b1, a1) =  1.000
#     C(a1, a4) =  1.000
#     C(b1, a4) =  1.000
#     C(b1, a3) = -0.273
#     C(a3, a4) = -0.271
#     C(a1, a3) = -0.266
#     C(a2, a3) =  0.171
# ...
# I-Star model RMSE of random predictions on medium volatility stocks : 0.9963975870038143
# ...

# %%
y = y_train_high
size = X_train_high['Size']
volatility = X_train_high['Volatility']
pov = X_train_high['POV']

params = Parameters()
params.add('b1', value=0.7, min=0.7, max=1)
params.add('a1', value=100, min=100, max=1000)
params.add('a2', value=0.1, min=0.1, max=1)
params.add('a3', value=0.1, min=0.1, max=1)
params.add('a4', value=0.1, min=0.1, max=1)

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'], param_names=params)
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, params=params)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_high['Size'], X_test_high['Volatility'], X_test_high['POV'], b1, a1, a2, a3, a4)

test_val = y_test_high
preds_val = preds
ar = np.arange(len(y_test_high))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')
iStar_MSE_high = istar_score(X_test_high, y_test_high)[0]
iStar_MAE_high = istar_score(X_test_high, y_test_high)[1]


plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on high volatility stocks : {}".format(iStar_MSE_high**(1/2)))
print("I-Star model MAE of random predictions on high volatility stocks : {}".format(iStar_MAE_high))
# Out:
# [[Model]]
#     Model(i_star_model)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 152
#     # data points      = 2483
#     # variables        = 5
#     chi-square         = 6444.52222
#     reduced chi-square = 2.60069500
#     Akaike info crit   = 2378.19352
#     Bayesian info crit = 2407.27963
# [[Variables]]
#     b1:  0.70000000 (init = 0.7)
#     a1:  111.931999 (init = 100)
#     a2:  0.10001860 (init = 0.1)
#     a3:  0.68047104 (init = 0.1)
#     a4:  0.99883085 (init = 0.1)
# ...
# I-Star model RMSE of random predictions on high volatility stocks : 1.659572986454128
# I-Star model MAE of random predictions on high volatility stocks : 0.9228768915396872

# %%
y = y_train_high
size = X_train_high['Size']
volatility = X_train_high['Volatility']
pov = X_train_high['POV']

istar_model = Model(i_star_model, independent_vars=['size', 'volatility', 'pov'],  param_names=['b1', 'a1', 'a2', 'a3', 'a4'])
result = istar_model.fit(y, size=size, volatility=volatility, pov=pov, b1=0.7, a1=10, a2=0.1, a3=0.1, a4=0.1)
print(result.fit_report())

a1 = result.best_values['a1']
a2 = result.best_values['a2']
a3 = result.best_values['a3']
a4 = result.best_values['a4']
b1 = result.best_values['b1']

preds = i_star_model(X_test_high['Size'], X_test_high['Volatility'], X_test_high['POV'], b1, a1, a2, a3, a4)

test_val = y_test_high
preds_val = preds
ar = np.arange(len(y_test_high))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (I-Star)')

iStar_MSE_high = istar_score(X_test_high, y_test_high)[0]
iStar_MAE_high = istar_score(X_test_high, y_test_high)[1]

plt.plot()
plt.show()
print("====================================================")
print("I-Star model RMSE of random predictions on high volatility stocks : {}".format(iStar_MSE_high**(1/2)))
print("I-Star model MAE of random predictions on high volatility stocks : {}".format(iStar_MAE_high))
# Out:
# [[Model]]
#     Model(i_star_model)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 810
#     # data points      = 2483
#     # variables        = 5
#     chi-square         = 6432.76687
#     reduced chi-square = 2.59595112
#     Akaike info crit   = 2373.66018
#     Bayesian info crit = 2402.74629
# [[Variables]]
#     b1:  3.1841e-04 +/- 0.00344226 (1081.08%) (init = 0.7)
#     a1:  31.9711903 +/- 8.53786839 (26.70%) (init = 10)
#     a2:  0.10055865 +/- 0.01503586 (14.95%) (init = 0.1)
#     a3:  0.67761008 +/- 0.01801424 (2.66%) (init = 0.1)
#     a4: -1.75630459 +/- 2.58868436 (147.39%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b1, a4) =  0.999
#     C(b1, a1) = -0.955
#     C(a1, a4) = -0.943
#     C(b1, a2) =  0.233
#     C(a2, a4) =  0.226
#     C(a1, a3) =  0.206
#     C(a1, a2) = -0.174
# ...
# I-Star model RMSE of random predictions on high volatility stocks : 1.6706462621035547
# ...

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel

def GPR_score(X_train, X_test, y_train, y_test):
    model = GaussianProcessRegressor(random_state=0)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    preds[preds < 0] = 0
    preds[preds > preds.std()*10] = preds.mean()
    
    return [mean_squared_error(y_test, preds), mean_absolute_error(y_test, preds)]

# %%
# kernel = DotProduct() + WhiteKernel()
model_GPR = GaussianProcessRegressor(random_state=0)
model_GPR.fit(X_train_low, y_train_low)
preds = model_GPR.predict(X_test_low)
preds[preds < 0] = 0
preds[preds > preds.std()*10] = preds.mean()

test_val = y_test_low
preds_val = preds
ar = np.arange(len(y_test_low))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (GPR)')
plt.plot()

GPR_MSE_low = GPR_score(X_train_low, X_test_low, y_train_low, y_test_low)[0]
GPR_MAE_low = GPR_score(X_train_low, X_test_low, y_train_low, y_test_low)[1]
plt.show()
print("===============================================")
print("GPR model predicting on low volatility stocks RMSE: {}".format(GPR_MSE_low**(1/2)))
print("GPR model prediction on low volatility stocks MAE: {}".format(GPR_MAE_low))
# Out:
# ...
# GPR model predicting on low volatility stocks RMSE: 0.7926427101191743
# GPR model prediction on low volatility stocks MAE: 0.578772345506778

# %%
model_GPR = GaussianProcessRegressor(random_state=0)
model_GPR.fit(X_train_medium, y_train_medium)
preds = model_GPR.predict(X_test_medium)
preds[preds < 0] = 0
preds[preds > preds.std()*10] = preds.mean()

test_val = y_test_medium
preds_val = preds
ar = np.arange(len(y_test_medium))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (GPR)')
plt.plot()

GPR_MSE_medium = GPR_score(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[0]
GPR_MAE_medium = GPR_score(X_train_medium, X_test_medium, y_train_medium, y_test_medium)[1]
plt.show()
print("===============================================")
print("GPR model predicting on medium volatility stocks RMSE: {}".format(GPR_MSE_medium**(1/2)))
print("GPR model prediction on medium volatility stocks MAE: {}".format(GPR_MAE_medium))
# Out:
# ...
# GPR model predicting on medium volatility stocks RMSE: 0.9575005199641251
# GPR model prediction on medium volatility stocks MAE: 0.6532301282253967

# %%
model_GPR = GaussianProcessRegressor(random_state=0)
model_GPR.fit(X_train_high, y_train_high)
preds = model_GPR.predict(X_test_high)
preds[preds < 0] = 0
preds[preds > preds.std()*10] = preds.mean()

test_val = y_test_high
preds_val = preds
ar = np.arange(len(y_test_high))
plt.plot(ar, np.zeros_like(ar) + test_val, 'o', c='y', label='Test data')
plt.plot(ar, np.zeros_like(ar) + preds_val, c='b', label='Predict data (GPR)')
plt.plot()

GPR_MSE_high = GPR_score(X_train_high, X_test_high, y_train_high, y_test_high)[0]
GPR_MAE_high = GPR_score(X_train_high, X_test_high, y_train_high, y_test_high)[1]
plt.show()
print("===============================================")
print("GPR model predicting on high volatility stocks RMSE: {}".format(GPR_MSE_high*(1/2)))
print("GPR model prediction on high volatility stocks MAE: {}".format(GPR_MAE_high))
# Out:
# ...
# GPR model predicting on high volatility stocks RMSE: 1.3114839310113242
# GPR model prediction on high volatility stocks MAE: 0.8818342030654988

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 2
iStar = (iStar_MSE_low**(1/2), iStar_MAE_low)

fig, ax = plt.subplots()

ind = np.arange(N)
width = 0.2
p1 = ax.bar(ind, iStar, width, color='y', bottom=0)

SVR = (SVR_MSE_low**(1/2), SVR_MAE_low)
p2 = ax.bar(ind + width, SVR, width, color='r', bottom=0)

GA_SVR = (GA_SVR_MSE_low**(1/2), GA_SVR_MAE_low)
p3 = ax.bar(ind + width*2, GA_SVR, width, color='b', bottom=0)

GPR = (GPR_MSE_low**(1/2), GPR_MAE_low)
p4 = ax.bar(ind + width*3, GPR, width, color='g', bottom=0)

ax.set_title('Errors of model predicting low volatility stocks')
ax.set_xticks(ind + width*(3/2))
ax.set_xticklabels(('RMSE', 'MAE'))

ax.legend((p1[0], p2[0], p3[0], p4[0]), ('I-Star', 'SVR', 'GA-SVR', 'GPR'))
ax.autoscale_view()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 2
iStar = (iStar_MSE_medium**(1/2), iStar_MAE_medium)

fig, ax = plt.subplots()

ind = np.arange(N)
width = 0.2
p1 = ax.bar(ind, iStar, width, color='y', bottom=0)

SVR = (SVR_MSE_medium**(1/2), SVR_MAE_medium)
p2 = ax.bar(ind + width, SVR, width, color='r', bottom=0)

GA_SVR = (GA_SVR_MSE_medium**(1/2), GA_SVR_MAE_medium)
p3 = ax.bar(ind + width*2, GA_SVR, width, color='b', bottom=0)

GPR = (GPR_MSE_medium**(1/2), GPR_MAE_medium)
p4 = ax.bar(ind + width*3, GPR, width, color='g', bottom=0)

ax.set_title('Errors of model predicting medium volatility stocks')
ax.set_xticks(ind + width*(3/2))
ax.set_xticklabels(('RMSE', 'MAE'))

ax.legend((p1[0], p2[0], p3[0], p4[0]), ('I-Star', 'SVR', 'GA-SVR', 'GPR'))
ax.autoscale_view()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 2
iStar = (iStar_MSE_high**(1/2), iStar_MAE_high)

fig, ax = plt.subplots()

ind = np.arange(N)
width = 0.2
p1 = ax.bar(ind, iStar, width, color='y', bottom=0)

SVR = (SVR_MSE_high**(1/2), SVR_MAE_high)
p2 = ax.bar(ind + width, SVR, width, color='r', bottom=0)

GA_SVR = (GA_SVR_MSE_high**(1/2), GA_SVR_MAE_high)
p3 = ax.bar(ind + width*2, GA_SVR, width, color='b', bottom=0)

GPR = (GPR_MSE_high**(1/2), GPR_MAE_high)
p4 = ax.bar(ind + width*3, GPR, width, color='g', bottom=0)

ax.set_title('Errors of model predicting high volatility stocks')
ax.set_xticks(ind + width*(3/2))
ax.set_xticklabels(('RMSE', 'MAE'))

ax.legend((p1[0], p2[0], p3[0], p4[0]), ('I-Star', 'SVR', 'GA-SVR', 'GPR'))
ax.autoscale_view()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 3
mse = (iStar_MSE_low, GPR_MSE_low, SVR_MSE_low)

fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.35         # the width of the bars
p1 = ax.bar(ind, mse, width, color='g', bottom=0)


mae = (iStar_MAE_low, GPR_MAE_low, SVR_MAE_low)

p2 = ax.bar(ind + width, mae, width, color='y', bottom=0)

ax.set_title('Errors of model predicting low volatility stocks')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('I-Star', 'GPR', 'SVR'))

ax.legend((p1[0], p2[0]), ('MSE', 'MAE'))
ax.autoscale_view()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 3
mse = (iStar_MSE_medium, GPR_MSE_medium, SVR_MSE_medium)

fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.35         # the width of the bars
p1 = ax.bar(ind, mse, width, color='g', bottom=0)


mae = (iStar_MAE_medium, GPR_MAE_medium, SVR_MAE_medium)

p2 = ax.bar(ind + width, mae, width, color='y', bottom=0)

ax.set_title('Errors of model predicting medium volatility stocks')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('I-Star', 'GPR', 'SVR'))

ax.legend((p1[0], p2[0]), ('MSE', 'MAE'))
ax.autoscale_view()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 3
mse = (iStar_MSE_high, GPR_MSE_high, SVR_MSE_high)

fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.35         # the width of the bars
p1 = ax.bar(ind, mse, width, color='g', bottom=0)


mae = (iStar_MAE_high, GPR_MAE_high, SVR_MAE_high)

p2 = ax.bar(ind + width, mae, width, color='y', bottom=0)

ax.set_title('Errors of model predicting high volatility stocks')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('I-Star', 'GPR', 'SVR'))

ax.legend((p1[0], p2[0]), ('MSE', 'MAE'))
ax.autoscale_view()

plt.show()

# %%
def estimate_market_impact_cost(params, cost):
    preds = model_GPR.predict(params)
    mki_cost = cost*preds/10000
    estimated_price = cost - mki_cost
    percent_loss = (estimated_price - cost)/cost*100
    print("Estimated actual price from total amount money: {} is {}, Loss: {}% From total money".format(cost, estimated_price[0], percent_loss[0]))
#     return estimated_price, percent_loss

# %%
preds = model_GPR.predict(X_test)
preds

# %%
params = pd.DataFrame([[0.28953, 0.02300, 0.0382]], columns = ['Size','Volatility','POV'])
params

# %%
estimate_market_impact_cost(params, 100000000)

# %%
# **************

preds = model_GPR.predict(pd.DataFrame([[0.28953, 0.02300, 0.0382]], columns = ['Size','Volatility','POV']))
preds

# %%
X_test

# %%
pd.DataFrame([[0.28953, 0.02300, 0.0382]], columns = ['Size','Volatility','POV'])
